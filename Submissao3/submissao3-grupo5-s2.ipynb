# %% [markdown]
# # 🧠 Claude 3.5 Sonnet – Human vs AI Text Classifier
# This notebook uses Anthropic's Claude 3.5 Sonnet model to classify whether each text input was written by a human or generated by AI.

# %% [markdown]
# ### 📦 Install the required package (if needed)

# %%
# !pip install anthropic

# %% [markdown]
# ### 📚 Import the required libraries

# %%
import os
import csv
import anthropic
import pandas as pd

# %% [markdown]
# ### 🔐 Define your API key

# %%
api_key="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"  # Replace with your real key

# %% [markdown]
# ### ✅ Validate the API key format

# %%
if not api_key or not api_key.startswith("sk-ant-"):
    raise ValueError("❌ CLAUDE_KEY inválida. A chave tem de começar por sk-ant-.")

# %% [markdown]
# ### 🤖 Initialize the Claude client

# %%
client = anthropic.Anthropic(api_key=api_key)

# %% [markdown]
# ### 📝 Build the prompt with instructions and examples

# %%
prompt = """
You are an advanced AI content detection system, designed to distinguish between texts written by humans and those generated by artificial intelligence.  
You will act as an automated evaluator similar to tools like GPTZero, analyzing the linguistic patterns, structure, and writing style of each passage to determine its most likely origin: Human or AI.

Instructions:
- Human: if the text is written by a human.
- AI: if the text is generated by an AI.
- Ignore the ID when analyzing the text.
- Output strictly in CSV format: ID;Label
- Use exactly \"Human\" or \"AI\" as labels.
- No explanations. No headers. No extra formatting.
-Example Input:
ID;Text  
E0-1;The use of statistical tools in climate modeling has evolved significantly over time.  
E0-2;Unlock the power of the universe with our AI-driven magic story generator.
-Example Output:
E0-1;Human  
E0-2;AI
"""

# %% [markdown]
# ### 📂 Read and format the input dataset

# %%
fileContent = ""
with open("data/submission3_inputs.csv", mode='r', encoding='utf-8') as file:
    reader = csv.reader(file, delimiter='\t')
    next(reader)  # Skip header
    for row in reader:
        fileContent += f"{row[0]};{row[1]}\n"

prompt += "\n### Input Dataset:\n" + fileContent

# %% [markdown]
# ### 📡 Send the prompt to Claude 3.5 Sonnet and get a prediction

# %%
message = client.messages.create(
    model="claude-3-5-sonnet-20241022",
    max_tokens=4000,          
    temperature=0.0,
    top_p=1,                  
    messages=[{"role": "user", "content": prompt}]
)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 message = client.messages.create(
#       2     model="claude-3-5-sonnet-20241022",
#       3     max_tokens=4000,
#       4     temperature=0.0,
#       5     top_p=1,
#       6     messages=[{"role": "user", "content": prompt}]
#       7 )
#
# File c:\Users\Typhon\miniconda3\envs\ap\lib\site-packages\anthropic\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File c:\Users\Typhon\miniconda3\envs\ap\lib\site-packages\anthropic\resources\messages\messages.py:953, in Messages.create(self, max_tokens, messages, model, metadata, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     946 if model in DEPRECATED_MODELS:
#     947     warnings.warn(
#     948         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     949         DeprecationWarning,
#     950         stacklevel=3,
#     951     )
# --> 953 return self._post(
#     954     "/v1/messages",
#     955     body=maybe_transform(
#     956         {
#     957             "max_tokens": max_tokens,
#     958             "messages": messages,
#     959             "model": model,
#     960             "metadata": metadata,
#     961             "stop_sequences": stop_sequences,
#     962             "stream": stream,
#     963             "system": system,
#     964             "temperature": temperature,
#     965             "thinking": thinking,
#     966             "tool_choice": tool_choice,
#     967             "tools": tools,
#     968             "top_k": top_k,
#     969             "top_p": top_p,
#     970         },
#     971         message_create_params.MessageCreateParams,
#     972     ),
#     973     options=make_request_options(
#     974         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     975     ),
#     976     cast_to=Message,
#     977     stream=stream or False,
#     978     stream_cls=Stream[RawMessageStreamEvent],
#     979 )
#
# File c:\Users\Typhon\miniconda3\envs\ap\lib\site-packages\anthropic\_base_client.py:1336, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1322 def post(
#    1323     self,
#    1324     path: str,
#    (...)
#    1331     stream_cls: type[_StreamT] | None = None,
#    1332 ) -> ResponseT | _StreamT:
#    1333     opts = FinalRequestOptions.construct(
#    1334         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1335     )
# -> 1336     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Typhon\miniconda3\envs\ap\lib\site-packages\anthropic\_base_client.py:1013, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1010 else:
#    1011     retries_taken = 0
# -> 1013 return self._request(
#    1014     cast_to=cast_to,
#    1015     options=options,
#    1016     stream=stream,
#    1017     stream_cls=stream_cls,
#    1018     retries_taken=retries_taken,
#    1019 )
#
# File c:\Users\Typhon\miniconda3\envs\ap\lib\site-packages\anthropic\_base_client.py:1117, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1114         err.response.read()
#    1116     log.debug("Re-raising status error")
# -> 1117     raise self._make_status_error_from_response(err.response) from None
#    1119 return self._process_response(
#    1120     cast_to=cast_to,
#    1121     options=options,
#    (...)
#    1125     retries_taken=retries_taken,
#    1126 )
#
# AuthenticationError: Error code: 401 - {'type': 'error', 'error': {'type': 'authentication_error', 'message': 'invalid x-api-key'}}

# %% [markdown]
# ### 🧾 Parse Claude's response into a clean format

# %%
results = message.content[0].text.strip().split('\n')
parsed = [row.split(';') for row in results if ';' in row]

# %% [markdown]
# ### 📊 Create a DataFrame with the final predictions

# %%
ids = [row[0] for row in parsed]
labels = [row[1] for row in parsed]
output_df = pd.DataFrame({"ID": ids, "Label": labels})

# %% [markdown]
# ### 💾 Save the output to a `.tsv` file

# %%
output_df.to_csv("submissao3-grupo5-s2.csv", sep="\t", index=False)
print("✅ Resultados guardados com sucesso em 'submissao3-grupo5-s2.csv'")
